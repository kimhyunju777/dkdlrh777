# %% [markdown]
# <a href="https://colab.research.google.com/github/kimhyunju777/dkdlrh777/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1주차 과제
#  과거, 4차 산업혁명으로 인공지능(AI)이 중요해질 거라는 뉴스를 접했을 때도, 영화 ‘아이언맨’을 보면서 토니스타크가 자비스를 부르며 보여주었던 인공지능도 그저 감탄은 하면서 저런 시대가 언제 올까? 하는 생각을 하던때가 생각납니다.
# 최근 인공지능은 기술의 진보를 거쳐 더 많은 양의 데이터와 보다 빠른 처리 능력, 그리고 더 강력한 알고리즘이 결합되어 더욱 널리 보급되고 있으며, 급속한 발전을 이루고 있습니다.
# 또한, 오늘날 인공지능의 발달에 따라 점차 우리 생활 속으로 스며들며 인공지능화가 되어 생활에 편리함을 주고 있습니다. 이렇듯 최근에는 인공지능 활용 사례가 늘고 있습니다. 우리 삶에서 쉽게 알수있는 인공지능의 대표적인 분야로 언어, 음성, 이미지, 자율주행 분야가 있습니다. 이 4가지 분야에 대해서 실 생활에 적용되고 있는 사례들을 알아보려고 합니다.
# 1. 첫번째로 언어입니다. 과거 군 전역 후 친구들과 필리핀을 3개월 가량 가게 되었고, 그 계기로 한국에 돌아와서도 외국인 친구와 카톡으로 연락을 하게 되었습니다. 하지만 부족한 영어 실력에 그 친구와 대화하는 것이 쉽지 않았습니다. 하지만 지금은 구글 번역기를 사용하여 쉽게 친구와 대화하고 있습니다. 매체에서는 AI를 이용한 신경망 기계번역기술이 발전해온 결과 어학공부를 하지 않아도 세계사람들과 의사소통할수 있는 시대가 왔다고 진단하기도 했습니다. 초기에는 정확도가 낮아 대략적 의미를 파악하는 정도였지만 최근에는 의미가 문제없이 전달되고 문장도 자연스러워 졌습니다. 또한 글로벌 영문 논문 교정, 번역, 저널 투고까지 논문 출판에 필요한 서비스를 제공하는 이나고(enago)가 인공지능 기술을 접목해 학술, 과학, 기술, 비즈니스 분야등에 쓸수 있는 영문 자동 교정 프로그램 Trinka(트링카)를 출시했습니다. 인공지능 기반 프로그램 트링카는 복잡한 언어도 세분화하하여 인식함으로써 복잡한 기술적인 언어뿐만 아니라 학술적인 언어 모두를 실시간으로 확인 및 교정이 가능하다고 합니다. 이렇듯 단순 대화 뿐만 아니라 전문적 지식을 포함한 언어까지도 상당한 데이터베이스를 보유하고 있어 소통, 영작을 누구나 쉽게 할수 있게 되었습니다.)
# 2. 두번째는 음성입니다. 강의를 들으면서 음성인식이 탑재된 인공지능 스피커 아리아를 보았습니다. 이름을 부르면 기다렸다는 듯 인사를 건네며, 음악, 날씨정보를 쉽게 얻을수 있으며, 심지어 농담까지 주고받는 장면은 큰 웃음을 주었습니다. 인공지능 기반 음성인식 제품에 말을 하면, “음성 입력 및 인식 -> 자연어 처리 -> 인식결과”의 단계를 거쳐 기계가 사람의 언어를 인식하고 반응한다고 합니다. 첫 번째 과정에서 음성 입력 과정을 거쳐 사람의 음성을 컴퓨터가 이해할 수 있도록 텍스트화 하는데 이런 기술을 STT(Speech To Text)라고 합니다. 두번째 과정은 자연어 처리(Natural Language Processing, NLP) 과정입니다. 자연어 처리란 컴퓨터가 자연어를 분석하여 이해하고 처리하는 기술입니다. 이 과정에서 자연어에 대한 형태소 분석, 구문 해석, 의미분석 등을 컴퓨터가 문장에 담긴 의도를 파악한다고 합니다. 앞선 과정을 거쳐 마지막으로 인식 결과를 내놓게 됩니다. 인식된 요청에 따라 가장 최적의 결과를 찾아내고, TTS(Text to speech)기술을 통해 사람의 말소리처럼 응답한다고 합니다.
# 3. 세번째는 이미지입니다. 요즘 사람들은 거의 대부분 핸드폰을 손에 쥐고 생활합니다. 그리고 이런 스마트폰에는 중요한 개인정보를 포함하기 때문에 보안장치가 중요한 부분을 차지합니다. 애플은 아이폰에 페이스ID를 탑재한 스마트폰을 선보였습니다. 기존 숫자 누르기, 패턴 그리기, 지문인식을 넘어서 스마트폰에 얼굴을 보이는 것만으로 사용자를 인식하는 최첨단 기술입니다. 인공지능이 등장하기 전 얼굴인식 기술은 사진 속 얼굴을 찾고 그 얼굴의 이목구비를 찾은 다음 길이와 비율 등을 데이터베이스화 하는 방식이였지만, 인공지능이 등장한 후에는 사진속 얼굴을 찾은 다음 픽셀 단위로 명암이 달라지는 지점을 찾아 데이터베이스화한 후 딥러닝 기반에 따라 스스로 얼굴을 학습해 빠르고 정확하게 얼굴을 인식합니다.
# 또한, 최근 코로나19로 전 세계적으로 불안한 가운데 LG CNS 마곡본사 일부 출입게이트에서 인공지능 얼굴인식 기술로 직원 신분을 판독함과 동시에 마스크 착용한 임직원만 통과시키는 서비스를 시작했다고 합니다. 마스크를 쓰지 않거나 턱이나 입에만 걸치는 경우를 분석해 “마스크를 착용해 주세요”라는 문구를 띄우고 게이트를 열어주지 않기도 합니다.
# 4. 마지막으로, 자율주행 분야입니다. 인공지능 시스템은 자율 주행이 가능하도록 급속하게 발전 중입니다. 인공지능 시스템을 통한 완전 자율주행 자동차는 운전자의 운전조작이 전혀 없이 자동차 스스로 주행 환경을 인식해 목표 지점까지 운행함에 따라 운전자의 부주의로 인한 교통하고를 미연에 예방하고, 편리한 운전 환경을 제공할수 있습니다. 자동차용 인공지능 모듈에는 머신러닝, 자연어 처리, 이미지처리, 음성인식 등의 다양한 모듈이 있습니다. 자동차용 인공지능 시스템은 라이다(Lider) 센서, 레이더, 초음파센서, 적외선 카메라, 모노/스트레오 카메라 등을 자동차 내외부에 설치하고 이러한 센서등을 통해 외부 정보를 수집해 분석한 후 자동차 스스로 주변 환경을 인식해 위험한 상황을 판단하고 주행 경로를 계획하는 등 운전자의 주행조작을 최소화하며, 스스로 안전한 주행이 가능하도록 해주는 시스템입니다. 자율주행 자동차의 핵심은 인공지능 시스템이며, 구글 등 관련 자동차 업계에서는 인공지능 시스템을 자율주행 자동차에 막대한 투자를 진행하고 으며, 구글은 300만km를 상회하는 테스트 주행을 통해 축척된 빅 테이터를 활용해 머신러닝으로 인공지능 시스템의 성능을 개선하고 있습니다. 국제자동차공학회(SAE)는 자율주행 단계를 5단계로 정의했습니다. 현재의 인공지능 시스템은 외부 센서에서 수집한 정보를 분석해 핸들 조작, 페달 작동을 통해 가속, 브레이크 작동, 차선유지, 앞차와의 안전거리 유지 및 주차 등에 활용(level1,2단계)하고 있습니다. 향후에 보다 많은 데이터로 학습한 인공지능 시스템은 위험한 운전상황 인식, 운전환경 모니터링, 고장대응, 도로 및 날씨 조건에 따른 최적 운전을(level3~5단계) 지원할 계획이라고 합니다. 테슬라가 2015년에 적응형 크루즈 콘트롤 기능을 model s에 적용했고, 볼보는 2016년에 자체 조종, 차선유지 기능을 xc90, s90에 적용하였습니다. GM과 아우디는 2017년 자체조종, 차선유지 기능과 교통정체 지원 기능을 적용하였으며, 구글은 현재 가장 많은 운행 기록을 가지고 이런 빅데이터를 수집하고 수집된 데이터를 인공지능을 활용해 학습하고 지속적으로 업데이트 하고 있습니다. 또한 2020년 현대 기아자동차는 스마트 크루즈 컨트롤(SCC) 앞차와의 거리를 일정하게 유지해 운전자가 설정한 속도록 자율주행을 해주는 기술을 더해 운전자의 주행성향에 맞는 부분 자율주행을 구현하는 SCC-ML기술을 개발하였고 신차에 선별적으로 적용할 예정이라고 합니다. 기존의 SCC는 앞차와의 거리, 가속성 등의 주행패턴을 운전자가 직접 설정해야 했으며 조절되는 단계가 세밀하지 않아 운전성향을 고스란히 반영할수 없었습니다. 이번 SCC-ML은 전방카메라, 레이더 등의 센서가 다양한 운전상황에서 발생되는 정보를 지속적으로 수집해 ADAS의 두뇌격인 제어컴퓨터로 보냅니다. 제어컴퓨터는 입력된 정보로부터 운전자의 주행습관을 추출해 종합적인 주행성향을 파악합니다. 이때 인공지능 기술 중 하나인 머신러닝 알고리즘이 적용됩니다. 저속으로 시내를 주행할 때는 앞차와의 차간거리를 매우 가깝게 유지하나 고속 주행시에는 차간거리를 멀게 유지할수도 있습니다. SCC-ML은 이러한 다양한 상황을 고려해 총 만개 이상의 패턴을 구분함으로써 어떤 운전자의 성향에도 맞출수 있습니다. 이런 자율 운전 차량들은 도로 정체, 운송비용과 시간 낭비를 줄일수 있으며 사람이 운전하는 것보다 더 안전한 주행이 될지도 모릅니다.
# 이처럼 인공지능은 많은 분야의 제품들에 적용되어 있으며, 우리는 인공지능에 많은 도움을 받고 살아가고 있습니다. 저도 생활하면서 알게 모르게 인공지능이 가미된 시스템, 제품을 사용하고 있는 것 같습니다. 생각해보면 너무 편리하지만 이런 기능까지 탑재되었다면 너무 좋겠다고 생각한것들 또한 있었습니다. 미래에는 좀더 스마트한 홈이 될것으로 생각합니다. 현재는 단순한 지시를 듣고 제품들이 독자적으로 작동하였다면 앞으로는 인공지능 제품이 집안의 요소를 고려 대화하며 상호작용하면 좋을 것 같다고 생각합니다. 예를 들어 tv를 시청하다가 맛있는 요리가 보인다면 냉장고에 지금 시청하고 있는 요리 재료들이 있을까를 물어보고, 없다면 마트와 연동되어 주문까지도 된다면 너무 편리할 것 같습니다. 또한 언어와 음성의 분야를 접목, 단순 언어를 컴퓨터에 적고 인식하여 번역하는 것을 넘어서 외국사람끼리 인공지능 제품을 통해 대화 도중 바로 통역이 되고 소통할수 있다면 국적이 다른 사람끼리도 쉽고 편하게 서로 교류하고 발전할수 있는 좋은 기회가 될것으로 생각합니다.
# 이제 인공지능은 디지털화된 빅데이터를 통해 세상의 정보를 학습하고, 단순히 지능을 갖는 것에서 뛰어넘어 인간과 같이 사고하는 단계까지 발전하게 될것으로 생각합니다. 강의를 듣고 인공지능 분야에 대하여 좀 더 궁금해졌고 더 자세히 공부하고 경험해보고 싶단 생각이 들었습니다.
